# %%
# !pip install nytimesarticle
# Out:
# ...
#   Running setup.py bdist_wheel for nytimesarticle ... done
#   Stored in directory: /Users/flatironschool/Library/Caches/pip/wheels/88/92/0f/d441bf1ccfcc3f98219f9d2f1c2277ccbe3521e35101f36229
# Successfully built nytimesarticle
# ...

# %%
from nytimesarticle import articleAPI
api = articleAPI('VXGCO6uStj3RB6nFAUAf6cKuAIMLGg9T')

# %%
articles = api.search(q="Obama")

# %%
articles
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2018/11/09/books/review-becoming-michelle-obama.html',
#     'snippet': 'The former first lady’s memoir is mostly about her childhood in Chicago, her marriage and her time in the White House, but she leaves room for some unequivocal criticism of President Trump.',
#     'lead_paragraph': 'The former first lady’s memoir is mostly about her childhood in Chicago, her marriage and her time in the White House, but she leaves room for some unequivocal criticism of President Trump.',
#     'print_page': '1',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
# ...
