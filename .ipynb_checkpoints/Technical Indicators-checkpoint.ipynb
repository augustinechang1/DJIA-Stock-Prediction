# %%
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import pandas as pd

# %%
ts = TimeSeries(key='X5AYBIDIH2EVGNW9', output_format='pandas')
stock, meta_data = ts.get_daily(symbol='DJIA', outputsize='full')
# stockdata['4. close'].plot()
# plt.title('Intraday Times Series for the DJIA stock (60 min)')
# plt.show()
stock = stock['4. close']
stock = pd.DataFrame({'date':stock.index, 'close':stock.values})

# %%
#Set Index Datetime
def equalizestock(time):
    time.index = pd.to_datetime(time.index)
    if time.index.name != 'date':
        time = time.set_index('date')
        time = time.loc['2010-01-31':'2019-01-28']
        return time
    else:
        time = time.loc['2010-01-31':'2019-01-28']
        return time

# %%
#Set Index Datetime
def equalize(time):
    time.index = pd.to_datetime(time.index)
    if time.index.name != 'date':
        time = time.set_index('date')
        time = time.loc['2010-02-01':'2019-01-28']
        return time
    else:
        time = time.loc['2010-02-01':'2019-01-28']
        return time

# %%
stock = equalizestock(stock)

# %%
stock = stock.pct_change()

# %%
stock = stock.loc['2010-02-02':'2019-01-28']

# %%
stock['close']
# Out:
# date
# 2010-02-02    0.010929
# 2010-02-03   -0.002554
# 2010-02-04   -0.026130
# 2010-02-05    0.001005
# 2010-02-08   -0.010371
# 2010-02-09    0.015164
# 2010-02-10   -0.002014
# 2010-02-11    0.010541
# 2010-02-12   -0.004441
# 2010-02-16    0.016800
# 2010-02-17    0.003937
# 2010-02-18    0.008115
# 2010-02-19    0.000909
# 2010-02-22   -0.001824
# 2010-02-23   -0.009724
# 2010-02-24    0.008923
# 2010-02-25   -0.005121
# 2010-02-26    0.000410
# 2010-03-01    0.007606
# 2010-03-02    0.000211
# 2010-03-03   -0.000886
# 2010-03-04    0.004557
# 2010-03-05    0.011687
# 2010-03-08   -0.001295
# 2010-03-09    0.001124
# 2010-03-10    0.000279
# 2010-03-11    0.004212
# 2010-03-12    0.001211
# 2010-03-15    0.001643
# 2010-03-16    0.004119
#                 ...
# 2018-12-13    0.002859
# 2018-12-14   -0.020200
# 2018-12-17   -0.021059
# 2018-12-18    0.003504
# 2018-12-19   -0.014867
# 2018-12-20   -0.019897
# 2018-12-21   -0.018121
# 2018-12-24   -0.029100
# 2018-12-26    0.049846
# 2018-12-27    0.011381
# 2018-12-28   -0.003303
# 2018-12-31    0.011493
# 2019-01-02    0.000805
# 2019-01-03   -0.028271
# 2019-01-04    0.032925
# 2019-01-07    0.004190
# 2019-01-08    0.010883
# 2019-01-09    0.003854
# 2019-01-10    0.005143
# 2019-01-11   -0.000249
# 2019-01-14   -0.003588
# 2019-01-15    0.006514
# 2019-01-16    0.005883
# 2019-01-17    0.006731
# 2019-01-18    0.013798
# 2019-01-22   -0.012218
# 2019-01-23    0.007013
# 2019-01-24   -0.000911
# 2019-01-25    0.007492
# 2019-01-28   -0.008448
# Name: close, Length: 2262, dtype: float64

# %%
stock['close'] = stock["close"].apply(lambda x: 0 if x<0 else 1)

# %%
stock = stock['close']

# %%
stock = equalize(stock)

# %%
stock.head()
# Out:
# date
# 2010-02-02    1
# 2010-02-03    0
# 2010-02-04    0
# 2010-02-05    1
# 2010-02-08    0
# Name: close, dtype: int64

# %%
ti = TechIndicators(key='X5AYBIDIH2EVGNW9', output_format='pandas')
ema, meta_data = ti.get_ema(symbol='DJIA', interval='daily')
# ema.plot()
# plt.title('EMA indicator for  DJIA stock')
# plt.show()
ema.head()
# Out:
#                    EMA
# date
# 2000-01-31  11281.2629
# 2000-02-01  11258.3855
# 2000-02-02  11234.0821
# 2000-02-03  11213.0686
# 2000-02-04  11189.3288

# %%
ema = equalize(ema)

# %%
macd, meta_data = ti.get_macd(symbol='DJIA', interval='daily')

# %%
macd = equalize(macd)
macd.head()
# Out:
#             MACD_Signal      MACD  MACD_Hist
# date
# 2010-02-01     -31.7711  -87.6854   -55.9142
# 2010-02-02     -41.5886  -80.8585   -39.2699
# 2010-02-03     -48.6082  -76.6864   -28.0782
# 2010-02-04     -57.6770  -93.9521   -36.2752
# 2010-02-05     -67.2630 -105.6070   -38.3440

# %%
stoch, meta_data = ti.get_stoch(symbol='DJIA', interval='daily')
stoch = equalize(stoch)
stoch.head()
# Out:
#               SlowK    SlowD
# date
# 2010-02-01  29.3506  21.7106
# 2010-02-02  53.9567  33.8944
# 2010-02-03  78.5878  53.9650
# 2010-02-04  59.4452  63.9966
# 2010-02-05  40.6318  59.5550

# %%
adx, meta_data = ti.get_adx(symbol='DJIA', interval='daily')
adx = equalize(adx)
adx.head()
# Out:
#                 ADX
# date
# 2010-02-01  19.2225
# 2010-02-02  19.3126
# 2010-02-03  19.3982
# 2010-02-04  20.2486
# 2010-02-05  21.4538

# %%
#Similar to RSI, 
cci, meta_data = ti.get_cci(symbol='DJIA', interval='daily')
cci = equalize(cci)
cci.head()
# Out:
#                  CCI
# date
# 2010-02-01 -106.5985
# 2010-02-02  -59.9591
# 2010-02-03  -51.3740
# 2010-02-04  -97.1015
# 2010-02-05 -122.2983

# %%
aroon, meta_data = ti.get_aroon(symbol='DJIA', interval='daily')
aroon = equalize(aroon)
aroon.head()
# Out:
#             Aroon Down  Aroon Up
# date
# 2010-02-01        95.0      55.0
# 2010-02-02        90.0      50.0
# 2010-02-03        85.0      45.0
# 2010-02-04       100.0      40.0
# 2010-02-05       100.0      35.0

# %%
ad, meta_data = ti.get_ad(symbol='DJIA', interval='daily')
ad = equalize(ad)
ad.head()
# Out:
#              Chaikin A/D
# date
# 2010-02-01  2.325163e+10
# 2010-02-02  2.342836e+10
# 2010-02-03  2.343357e+10
# 2010-02-04  2.313850e+10
# 2010-02-05  2.338503e+10

# %%
obv, meta_data = ti.get_obv(symbol='DJIA', interval='daily')
obv = equalize(obv)
obv.head()
# Out:
#                      OBV
# date
# 2010-02-01  1.453225e+10
# 2010-02-02  1.476939e+10
# 2010-02-03  1.457045e+10
# 2010-02-04  1.426621e+10
# 2010-02-05  1.457453e+10

# %%
bbands, meta_data = ti.get_bbands(symbol='DJIA', interval='daily')
bbands = equalize(bbands)
bbands.head()
# Out:
#             Real Upper Band  Real Lower Band  Real Middle Band
# date
# 2010-02-01       10904.9997       10008.9004        10456.9500
# 2010-02-02       10891.8431        9993.3460        10442.5945
# 2010-02-03       10878.6143        9976.4278        10427.5210
# 2010-02-04       10880.7444        9917.1477        10398.9460
# 2010-02-05       10869.0724        9869.3567        10369.2146

# %%
result = pd.concat([stock, ema, macd, stoch, adx, cci, aroon, ad, obv, bbands], axis=1, sort=False)
# 2018-12-27  4.397731e+10       26276.5668       21939.3561        24107.9614
# 2018-12-28  4.364080e+10       26126.2207       21859.2992        23992.7600
# 2018-12-31  4.392963e+10       25950.6702       21833.7118        23892.1910
# 2019-01-02  4.425120e+10       25707.8981       21857.2619        23782.5800
# 2019-01-03  4.382696e+10       25361.4201       21889.7190        23625.5695
# 2019-01-04  4.422298e+10       25159.0495       21932.6986        23545.8740
# 2019-01-07  4.455718e+10       24954.6901       21995.4259        23475.0580
# 2019-01-08  4.487460e+10       24872.6284       22017.3376        23444.9830
# 2019-01-09  4.519917e+10       24789.4539       22046.0981        23417.7760
# 2019-01-10  4.553732e+10       24728.6270       22070.0929        23399.3600
# 2019-01-11  4.527467e+10       24630.1227       22115.4652        23372.7939
# 2019-01-14  4.499711e+10       24493.3669       22183.4669        23338.4169
# 2019-01-15  4.528868e+10       24487.1040       22186.2378        23336.6709
# 2019-01-16  4.559151e+10       24574.9127       22159.8470        23367.3799
# 2019-01-17  4.588010e+10       24680.9294       22123.2763        23402.1028
# 2019-01-18  4.625307e+10       24869.5435       22072.9311        23471.2373
# 2019-01-22  4.591459e+10       24973.5295       22123.4332        23548.4813
# 2019-01-23  4.623319e+10       25052.4965       22257.4912        23654.9938
# 2019-01-24  4.591302e+10       24952.4202       22633.6716        23793.0459
# 2019-01-25  4.628991e+10       25035.1513       22736.8155        23885.9834
# 2019-01-28  4.594274e+10       25083.3389       22827.5679        23955.4534
#
# [2263 rows x 16 columns]

# %%
Y = result['close'].fillna(0)
Y = Y.astype(int)
Y = pd.get_dummies(Y.values).values
Y[0]
# Out:
# array([1, 0], dtype=uint8)

# %%
X = result.drop(['close'],axis =1)
X = X.as_matrix()
X
# Out:
# /Users/flatironschool/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# array([[ 1.03606285e+04, -3.17711000e+01, -8.76854000e+01, ...,
#          1.09049997e+04,  1.00089004e+04,  1.04569500e+04],
#        [ 1.03545543e+04, -4.15886000e+01, -8.08585000e+01, ...,
#          1.08918431e+04,  9.99334600e+03,  1.04425945e+04],
#        [ 1.03465539e+04, -4.86082000e+01, -7.66864000e+01, ...,
#          1.08786143e+04,  9.97642780e+03,  1.04275210e+04],
#        ...,
#        [ 2.40660538e+04,  1.09000000e-01,  1.54366700e+02, ...,
#          2.49524202e+04,  2.26336716e+04,  2.37930459e+04],
#        [ 2.41299725e+04,  3.71121000e+01,  1.85124400e+02, ...,
#          2.50351513e+04,  2.27368155e+04,  2.38859834e+04],
#        [ 2.41679009e+04,  6.77780000e+01,  1.90441900e+02, ...,
#          2.50833389e+04,  2.28275679e+04,  2.39554534e+04]])

# %%
import numpy as np
import seaborn as sns
#Features to remove from the plot:
features_to_remove = ['close']
corr = result.drop(features_to_remove, axis=1).corr() 
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Heatmap of Correlation between Features')
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation between Features')

# %%
result.corr()

# %%
# !pip install statsmodels

# %%
# !pip install plotly

# %%
# !pip install tf

# %%
import matplotlib.pyplot as plt
import statsmodels.tsa.seasonal as smt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
import datetime as dt
from sklearn import linear_model 
from sklearn.metrics import mean_absolute_error
import plotly

# import the relevant Keras modules
from keras.models import Sequential
from keras.layers import Activation, Dense, Embedding, TimeDistributed
from keras.layers import LSTM
from keras.layers import Dropout, Flatten

from sklearn.model_selection import train_test_split
from tf.keras.layers import AveragePooling1D
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-9a47700149f5> in <module>
#      16
#      17 from sklearn.model_selection import train_test_split
# ---> 18 from tf.keras.layers import AveragePooling1D
#
# ModuleNotFoundError: No module named 'tf.keras'; 'tf' is not a package

# %%
embed_dim = 2263
lstm_out = 200
batch_size = 32

model = Sequential()

model.add(Dense(15, input_shape = (1810, 15), activation = 'relu'))
# model.add(Embedding(15, embed_dim, dropout = 0.2))
# model.add(Flatten())
# model.add(LSTM(lstm_out, dropout_U = 0.2, dropout_W = 0.2, return_sequences = False))
# model.add(Dropout(0.2))
# output2 = model.outputs
#print(output2.shape)
model.add(Dense(2, activation='softmax'))

model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())

# %%
X_valid.shape
# Out:
# (453, 15)

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(X,Y, test_size = 0.20, random_state = 36)

#Here we train the Network.

# model.fit(X_train, Y_train, batch_size =batch_size, nb_epoch = 1,  verbose = 5)

# %%
X_train = X_train.reshape(1810, 1, 15)
X_valid = X_valid.reshape(453, 1, 15)
Y_train = Y_train.reshape(1810, 2)
Y_valid = Y_valid.reshape(453, 2)
X_train.shape, Y_train.shape
# Out:
# ((1810, 1, 15), (1810, 2))

# %%
# X_train = X_train.reshape((1810, 1 * 15))
# Y_train = to_categorical(Y_train)
Y_train = Y_train.reshape((1, 1810*2))
Y_train.shape
# Out:
# (1, 3620)

# %%
print(X_train.ndim)      # 3
print(X_train[0].ndim)   # 2
print(X_train.shape)     # (60000, 28, 28)
print(X_train[0].shape)  # (28, 28)

print(Y_train.ndim)       # 1
print(Y_train[0].ndim)    # 0
print(Y_train.shape)      # (10000,)
print(Y_train[0].shape)   # ()
# Out:
# 3
# 2
# (1810, 1, 15)
# (1, 15)
# 2
# 1
# (1810, 2)
# (2,)

# %%
Y_train = to_categorical(Y_train)
Y_train.shape
# Out:
# (1, 3620, 2)

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(1, 15)))
model.add(Dense(2, activation="softmax"))
model.compile(loss='mean_absolute_error', optimizer='adam')
model.fit(X_train, Y_train, epochs=10, batch_size=600, verbose=1, validation_data=(X_valid, Y_valid))
# Out:
# Train on 1810 samples, validate on 453 samples
# Epoch 1/10

# %%
model = Sequential()
model.add(LSTM(24, input_shape=(1810, 15), return_sequences=True, implementation=2))
model.add(TimeDistributed(Dense(1)))
# model.add(AveragePooling1D())

model.add(Flatten())

model.add(Dense(2, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam')
model.fit(X_train, Y_train, epochs=10, batch_size=600, verbose=1, validation_data=(X_valid, Y_valid))

# %%
def build_model(inputs, output_size, neurons, activ_func="softmax",
                dropout=0.40, loss="binary_crossentropy", optimizer="adam"):
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(inputs.shape[0], inputs.shape[1])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))
    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
build_model(X, 2, 2)

model.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-129f0078b26b> in <module>
#       1 build_model(X, 2, 2)
#       2
# ----> 3 model.fit(X_train)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     137     indices_for_conversion_to_dense = []
#     138     for i in range(len(feed)):
# --> 139         if issparse(ins[i]) and not K.is_sparse(feed[i]):
#     140             indices_for_conversion_to_dense.append(i)
#     141
#
# IndexError: list index out of range

# %%
output2[0].shape
for layer in model.layers:
    print(layer.name)
# Out:
# embedding_17
# lstm_17
# dense_9

# %%
X_train.shape
# Out:
# (1810, 15)

# %%
Y_train.shape
# Out:
# (1810, 2, 2, 2)
